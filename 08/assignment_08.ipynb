# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ## import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib import ticker, cm

# %% [markdown]
# ## load training data

# %%
fname_data = 'assignment_08_data.csv'

data        = np.genfromtxt(fname_data, delimiter=',')
number_data = data.shape[0]

point_x = data[:, 0]
point_y = data[:, 1]
label   = data[:, 2]

print('number of data = ', number_data)
print('data type of point x = ', point_x.dtype)
print('data type of point y = ', point_y.dtype)

point_x_class_0 = point_x[label == 0]
point_y_class_0 = point_y[label == 0]

point_x_class_1 = point_x[label == 1]
point_y_class_1 = point_y[label == 1]
# Out:
# number of data =  600
# data type of point x =  float64
# data type of point y =  float64

# %% [markdown]
# ## plot the data

# %%
f = plt.figure(figsize=(8,8))   

plt.title('training data')
plt.plot(point_x_class_0, point_y_class_0, 'o', color='blue', label='class = 0')
plt.plot(point_x_class_1, point_y_class_1, 'o', color='red', label='class = 1')
plt.axis('equal')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## define the linear regression function

# %% [markdown]
# - $\theta = (\theta_0, \theta_1, \theta_2)$
# - point = $(1, x, y) \in \mathbb{R}^3$

# %%
def compute_linear_regression(theta, point):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    #value = np.matmul(np.transpose(theta), point)
    value = np.inner(np.transpose(theta), point)
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return value

# %% [markdown]
# ## define sigmoid function with input

# %% [markdown]
# - $z \in \mathbb{R}$

# %%
def sigmoid(z):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    value = 1/(1+np.exp(-z))
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return value

# %% [markdown]
# ## define the logistic regression function

# %% [markdown]
# - $\theta = (\theta_0, \theta_1, \theta_2) \in \mathbb{R}^3$
# - point = $(1, x, y) \in \mathbb{R}^3$

# %%
def compute_logistic_regression(theta, point):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    value = sigmoid(compute_linear_regression(theta, point))
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return value

# %% [markdown]
# ## define the residual function

# %% [markdown]
# - $\theta = (\theta_0, \theta_1, \theta_2) \in \mathbb{R}^3$
# - point $= (x, y) \in \mathbb{R}^2$
# - label $= l \in \{0, 1\}$

# %%
def compute_residual(theta, point, label):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    residual = -label*np.log(compute_logistic_regression(theta, point)) - (1-label)*np.log(1-compute_logistic_regression(theta, point))
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return residual

# %% [markdown]
# ## define the loss function for the logistic regression

# %% [markdown]
# - $\theta = (\theta_0, \theta_1, \theta_2) \in \mathbb{R}^3$
# - point $= (1, x, y) \in \mathbb{R}^3$
# - label $= l \in \{0, 1\}$

# %%
def compute_loss(theta, point, label):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    loss = (1/data.shape[0])*np.sum(compute_residual(theta, point, label))
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return loss

# %% [markdown]
# ## define the gradient of the loss with respect to the model parameter $\theta$

# %% [markdown]
# - $\theta = (\theta_0, \theta_1, \theta_2) \in \mathbb{R}^3$
# - point $= (1, x, y) \in \mathbb{R}^3$
# - label $= l \in \{0, 1\}$

# %%
def compute_gradient(theta, point, label):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    gradient = (1/data.shape[0])*np.matmul(np.transpose(point), compute_residual(theta, point, label))
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return gradient

# %% [markdown]
# ## initialize the gradient descent algorithm

# %%
num_iteration   = 5000  # USE THIS VALUE for the number of gradient descent iterations 
learning_rate   = 0.001 # USE THIS VALUE for the learning rate

theta           = np.array((0, 0, 0))
theta_iteration = np.zeros((num_iteration, theta.size))
loss_iteration  = np.zeros(num_iteration)

number_point_class_0    = len(point_x_class_0)
number_point_class_1    = len(point_x_class_1)

point_class_0   = np.ones((number_point_class_0, 3))
point_class_1   = np.ones((number_point_class_1, 3))

point_class_0[:, 1] = point_x_class_0
point_class_0[:, 2] = point_y_class_0
 
point_class_1[:, 1] = point_x_class_1
point_class_1[:, 2] = point_y_class_1

label_0     = np.zeros(number_point_class_0)
label_1     = np.ones(number_point_class_1)

point = np.concatenate((point_class_0, point_class_1), axis=0)
label = np.concatenate((label_0, label_1), axis=0)

print('shape of point_class_0 : ', point_class_0.shape)
print('shape of point_class_1 : ', point_class_1.shape)
print('shape of label_0 : ', label_0.shape)
print('shape of label_1 : ', label_1.shape)

print('shape of point : ', point.shape)
print('shape of label : ', label.shape)
# Out:
# shape of point_class_0 :  (300, 3)
# shape of point_class_1 :  (300, 3)
# shape of label_0 :  (300,)
# shape of label_1 :  (300,)
# shape of point :  (600, 3)
# shape of label :  (600,)

# %% [markdown]
# ## run the gradient descent algorithm to optimize the loss function with respect to the model parameter

# %%
for i in range(num_iteration):
    
    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    theta   = theta - learning_rate*compute_gradient(theta, point, label)
    loss    = compute_loss(theta, point, label)
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    theta_iteration[i, :]   = theta
    loss_iteration[i]       = loss

theta_optimal = theta
# Out:
# <ipython-input-16-dfb6f0c36282>:6: RuntimeWarning: divide by zero encountered in log
#   residual = -label*np.log(compute_logistic_regression(theta, point)) - (1-label)*np.log(1-compute_logistic_regression(theta, point))
# <ipython-input-18-c274cd256a8d>:6: RuntimeWarning: invalid value encountered in matmul
#   gradient = (1/data.shape[0])*np.matmul(np.transpose(point), compute_residual(theta, point, label))
# <ipython-input-16-dfb6f0c36282>:6: RuntimeWarning: invalid value encountered in multiply
#   residual = -label*np.log(compute_logistic_regression(theta, point)) - (1-label)*np.log(1-compute_logistic_regression(theta, point))

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ## functions for presenting the results

# %% [markdown]
# ___

# %% [markdown]
# ___

# %%
def function_result_01():

    input1  = np.array([0.1, 0.2, 0.3])
    input2  = np.array([[1, 2, 3], [1, -2, -3]])

    value = compute_linear_regression(input1, input2)
    
    print(value)

# %%
def function_result_02():
    
    input1  = np.array([0.1, 0.2, 0.3])
    input2  = np.array([[1, 2, 3], [1, -2, -3]])

    value = compute_logistic_regression(input1, input2)

    print(value)

# %%
def function_result_03():

    input1  = np.array([0.1, 0.2, 0.3])
    input2  = np.array([[1, 2, 3], [1, -2, -3]])
    input3  = np.array([0, 1])

    value = compute_residual(input1, input2, input3)

    print(value)

# %%
def function_result_04():
    
    input1  = np.array([0.1, 0.2, 0.3])
    input2  = np.array([[1, 2, 3], [1, -2, -3]])
    input3  = np.array([[0], [1]])

    value = compute_loss(input1, input2, input3)

    print(value)

# %%
def function_result_05():
    
    input1  = np.array([0.1, 0.2, 0.3])
    input2  = np.array([[1, 2, 3], [1, -2, -3]])
    input3  = np.array([[0], [1]])

    value = compute_gradient(input1, input2, input3)

    print(value)

# %%
def function_result_06():
    
    plt.figure(figsize=(8,6))
    plt.title('loss')

    plt.plot(loss_iteration, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')

    plt.tight_layout()
    plt.show()

# %%
def function_result_07():
    
    plt.figure(figsize=(8,6))   # USE THIS VALUE for the size of the figure
    plt.title('model parameter')

    plt.plot(theta_iteration[:, 0], '-', color='red', label=r'$\theta_0$')
    plt.plot(theta_iteration[:, 1], '-', color='green', label=r'$\theta_1$')
    plt.plot(theta_iteration[:, 2], '-', color='blue', label=r'$\theta_2$')
    
    plt.xlabel('iteration')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## plot the linear regression values over the 2-dimensional Euclidean space and superimpose the training data

# %%
def function_result_08():

    X = np.arange(-20, 35, 0.1) # USE THIS VALUE for the range of x values in the construction of coordinate
    Y = np.arange(-20, 35, 0.1) # USE THIS VALUE for the range of y values in the construction of coordinate

    [XX, YY] = np.meshgrid(X, Y)

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    plt.figure(figsize=(8,8))
    ax = plt.gca()
    plt.plot(point_x_class_0 ,point_y_class_0, 'o', color='blue', label='class=0')
    plt.plot(point_x_class_1 ,point_y_class_1, 'o', color='red', label='class=1')
    plt.plot(compute_linear_regression(theta, point), '-', color='black')
    #ZZ = compute_linear_regression(theta, np.c_[np.ones(X.shape[0]),X,Y])
    #c = plt.pcolormesh(XX,YY,ZZ, cmap="RdBu_r")
    #plt.colorbar(c)
    plt.title('linear regression values')
    ax.legend()
    plt.xlim([-20, 40])
    plt.ylim([-20, 40])
    plt.show()
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
function_result_08()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import DivergingNorm

x, y = np.meshgrid(np.linspace(0,50,51), np.linspace(0,50,51))
z = np.linspace(-2,4,50*50).reshape(50,50)

#norm = DivergingNorm(vmin=z.min(), vcenter=0, vmax=z.max())
pc = plt.pcolormesh(x,y,z, cmap="RdBu_r")
plt.colorbar(pc)

plt.show()

# %% [markdown]
# ## plot the logistic regression values over the 2-dimensional Euclidean space

# %%
def function_result_09():

    X = np.arange(-20, 35, 0.1) # USE THIS VALUE for the range of x values in the construction of coordinate
    Y = np.arange(-20, 35, 0.1) # USE THIS VALUE for the range of y values in the construction of coordinate

    [XX, YY] = np.meshgrid(X, Y)

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    plt.figure(figsize=(8,8))
    ax = plt.gca()
    plt.plot(point_x_class_0 ,point_y_class_0, 'o', color='blue', label='class=0')
    plt.plot(point_x_class_1 ,point_y_class_1, 'o', color='red', label='class=1')
    
    ZZ = compute_logistic_regression(theta, np.c_[np.ones(X.shape[0]),X,Y])
    c = plt.pcolormesh(XX,YY,ZZ, cmap="RdBu_r")
    plt.colorbar(c)
    
    plt.title('logistic regression values')
    ax.legend()
    plt.show()
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
function_result_09()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-7356709acb79> in <module>
# ----> 1 function_result_09()
#
# <ipython-input-107-ba2d48ffc337> in function_result_09()
#      15
#      16     ZZ = compute_logistic_regression(theta, np.c_[np.ones(X.shape[0]),X,Y])
# ---> 17     c = plt.pcolormesh(XX,YY,ZZ, cmap="RdBu_r")
#      18     plt.colorbar(c)
#      19
#
# c:\Users\cocor\anaconda3\lib\site-packages\matplotlib\pyplot.py in pcolormesh(alpha, norm, cmap, vmin, vmax, shading, antialiased, data, *args, **kwargs)
#    2799         vmax=None, shading=None, antialiased=False, data=None,
#    2800         **kwargs):
# -> 2801     __ret = gca().pcolormesh(
#    2802         *args, alpha=alpha, norm=norm, cmap=cmap, vmin=vmin,
#    2803         vmax=vmax, shading=shading, antialiased=antialiased,
#
# c:\Users\cocor\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\Users\cocor\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6091         kwargs.setdefault('edgecolors', 'None')
#    6092
# -> 6093         X, Y, C, shading = self._pcolorargs('pcolormesh', *args,
#    6094                                             shading=shading)
#    6095         Ny, Nx = X.shape
#
# c:\Users\cocor\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _pcolorargs(funcname, shading, *args)
#    5580                 if isinstance(Y, np.ma.core.MaskedArray):
#    5581                     Y = Y.data
# -> 5582             nrows, ncols = C.shape
#    5583         else:
#    5584             raise TypeError(f'{funcname}() takes 1 or 3 positional arguments '
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ## results

# %% [markdown]
# ___

# %% [markdown]
# ___

# %%
number_result = 9

for i in range(number_result):
    title = '## [RESULT {:02d}]'.format(i+1)
    name_function = 'function_result_{:02d}()'.format(i+1)

    print('**************************************************')
    print(title)
    print('**************************************************')
    eval(name_function)
# Out:
# **************************************************
# ## [RESULT 01]
# **************************************************
# [ 1.4 -1.2]
# **************************************************
# ## [RESULT 02]
# **************************************************
# [0.80218389 0.23147522]
# **************************************************
# ## [RESULT 03]
# **************************************************
# [1.62041741 1.46328247]
# **************************************************
# ## [RESULT 04]
# **************************************************
# 0.005945666257521607
# **************************************************
# ## [RESULT 05]
# **************************************************
# [[ 0.00306806  0.00287761]
#  [ 0.00466667 -0.004     ]
#  [ 0.007      -0.006     ]]
# **************************************************
# ## [RESULT 06]
# **************************************************
# **************************************************
# ## [RESULT 07]
# **************************************************
# **************************************************
# ## [RESULT 08]
# **************************************************
# **************************************************
# ## [RESULT 09]
# **************************************************
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-132-15c24b10a6a2> in <module>
#       8     print(title)
#       9     print('**************************************************')
# ---> 10     eval(name_function)
#
# <string> in <module>
#
# <ipython-input-107-ba2d48ffc337> in function_result_09()
#      15
#      16     ZZ = compute_logistic_regression(theta, np.c_[np.ones(X.shape[0]),X,Y])
# ---> 17     c = plt.pcolormesh(XX,YY,ZZ, cmap="RdBu_r")
#      18     plt.colorbar(c)
#      19
#
# c:\Users\cocor\anaconda3\lib\site-packages\matplotlib\pyplot.py in pcolormesh(alpha, norm, cmap, vmin, vmax, shading, antialiased, data, *args, **kwargs)
#    2799         vmax=None, shading=None, antialiased=False, data=None,
#    2800         **kwargs):
# -> 2801     __ret = gca().pcolormesh(
#    2802         *args, alpha=alpha, norm=norm, cmap=cmap, vmin=vmin,
#    2803         vmax=vmax, shading=shading, antialiased=antialiased,
#
# c:\Users\cocor\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\Users\cocor\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6091         kwargs.setdefault('edgecolors', 'None')
#    6092
# -> 6093         X, Y, C, shading = self._pcolorargs('pcolormesh', *args,
#    6094                                             shading=shading)
#    6095         Ny, Nx = X.shape
#
# c:\Users\cocor\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _pcolorargs(funcname, shading, *args)
#    5580                 if isinstance(Y, np.ma.core.MaskedArray):
#    5581                     Y = Y.data
# -> 5582             nrows, ncols = C.shape
#    5583         else:
#    5584             raise TypeError(f'{funcname}() takes 1 or 3 positional arguments '
#
# ValueError: not enough values to unpack (expected 2, got 1)
